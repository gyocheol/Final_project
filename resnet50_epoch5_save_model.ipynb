# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.8.0'

# %%
# !apt install fonts-nanum -y

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

## 한글 폰트 설정하기
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')
matplotlib.font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# 구글 계정 액세스
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = "/content/drive/MyDrive/Colab/all"
image_list = os.listdir(path)
image_list_png = [image for image in image_list if image.endswith(".png")]

print('image_list_png :{}'.format(image_list_png))
# Out:
# image_list_png :[]

# %%
import PIL
import glob

imgs = glob.glob('/content/drive/MyDrive/Colab/all/*.png')

for img in imgs:
    try:
        img = PIL.Image.open(img)
    except PIL.UnidentifiedImageError:
        print(img)

# %%
# 훈련 검증, 테스트 폴더로 이미지 복사 
import os, shutil
original_dataset_dir = '/content/drive/MyDrive/Colab/all/'

folder_list = []
for path_ in os.listdir(original_dataset_dir):
    if path_.startswith('.'):
        pass
    else:
        path2 = original_dataset_dir + path_
        folder_list.append(path_)
        
print(folder_list)

plant_cnt = {}
for path in folder_list:
    plant_cnt[path] = len(os.listdir(original_dataset_dir+path))
    
print(plant_cnt)
# Out:
# ['geumjeonsoo', 'tableyaja', 'monstera', 'yeoincho', 'stuckyi']
# {'geumjeonsoo': 1509, 'tableyaja': 991, 'monstera': 425, 'yeoincho': 567, 'stuckyi': 363}

# %%
# datasets 파일 만들기
base_dir = '/content/datasets/' 
os.mkdir(base_dir)
# datasets 파일 안에 Plant 파일 만들기
base_dir = '/content/datasets/Plant' # 소규모 데이터셋 저장할 디렉토리
os.mkdir(base_dir)

# %%
train_dir = os.path.join(base_dir, 'train')
# valid_dir = os.path.join(base_dir, 'valid')
test_dir = os.path.join(base_dir, 'test')

os.mkdir(train_dir)
# os.mkdir(valid_dir)
os.mkdir(test_dir)

# %%
# 이미지 데이터 이름 변경 (순서매기기)
for path in folder_list:
    i = 1
    for imgPath in os.listdir(original_dataset_dir+path):
        src = os.path.join(original_dataset_dir+path, imgPath)
        dst_ = path + '_' + str(i) + '.png'
        dst = os.path.join(original_dataset_dir+path, dst_)
        
        print(src)
        print(dst)
        print('-' * 40)
        
        os.rename(src, dst)
        i += 1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_680.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1737.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_681.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1752.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_682.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1748.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_683.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1753.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_684.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1751.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_685.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1749.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_686.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1757.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_687.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1756.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_688.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1750.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_689.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1754.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_690.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1755.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_691.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1764.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_692.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1759.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_693.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1766.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_694.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1765.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_695.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1763.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_696.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1767.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_697.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1760.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_698.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1758.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_699.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1761.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_700.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1768.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_701.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1772.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_702.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1776.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_703.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1777.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_704.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1769.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_705.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1773.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_706.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1775.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_707.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1770.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_708.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1781.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_709.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1786.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_710.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1778.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_711.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1780.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_712.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1782.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_713.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1779.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_714.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1785.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_715.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1783.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_716.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1784.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_717.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1793.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_718.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1797.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_719.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1792.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_720.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1788.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_721.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1789.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_722.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1794.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_723.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1796.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_724.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1795.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_725.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1799.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_726.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1802.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_727.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1807.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_728.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1805.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_729.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1800.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_730.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1806.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_731.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1801.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_732.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1809.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_733.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1808.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_734.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1814.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_735.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1818.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_736.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1819.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_737.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1816.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_738.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1817.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_739.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1812.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_740.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1815.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_741.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1813.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_742.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1811.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_743.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1810.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja_744.png
# ----------------------------------------
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja1821.png
# /content/drive/MyDrive/Colab/all/tableyaja/tableyaja
            fnames = ['{}_{}.png'.format(plant, i+1) for i in range(0,cnt)]
            print(cnt)
            print(plant,'- train_dir len :', len(fnames))
        
        # elif dataset == data_list[1]:
        #     cnt = int(int(plant_cnt[plant])/2)
        #     cnt3 = int((int(plant_cnt[plant])/4)*3)
        #     fnames = ['{}_{}.png'.format(plant, i+1) for i in range(cnt,cnt3)]
        #     print(plant,'- valid_dir len :', len(fnames))
#         print("fnames : ",fnames)
        else :
            cnt3 = int((int(plant_cnt[plant])/4)*3)
            fnames = ['{}_{}.png'.format(plant, i+1) for i in range(cnt3,plant_cnt[plant])]
            print(plant, '-test_dir len :', len(fnames))
            
        for fname in fnames:
            src = os.path.join(original_dataset_dir,plant)
            src2 = os.path.join(src,fname)
            dst = os.path.join(filePath_,fname)
#             print(src2)
            print('dst :',dst)
            shutil.copyfile(src2,dst)
# Out:
# dataset :  /content/datasets/Plant/train
# 754
# geumjeonsoo - train_dir len : 754
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_1.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_2.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_3.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_4.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_5.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_6.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_7.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_8.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_9.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_10.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_11.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_12.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_13.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_14.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_15.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_16.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_17.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_18.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_19.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_20.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_21.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_22.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_23.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_24.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_25.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_26.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_27.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_28.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_29.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_30.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_31.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_32.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_33.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_34.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_35.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_36.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_37.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_38.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_39.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_40.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_41.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_42.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_43.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_44.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_45.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_46.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_47.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_48.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_49.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_50.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_51.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_52.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_53.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_54.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_55.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_56.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_57.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_58.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_59.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_60.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_61.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_62.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_63.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_64.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_65.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_66.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_67.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_68.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_69.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_70.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_71.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_72.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_73.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_74.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_75.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_76.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_77.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_78.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_79.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_80.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_81.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_82.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_83.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_84.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_85.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_86.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_87.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_88.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_89.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_90.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_91.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_92.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_93.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_94.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_95.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_96.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_97.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_98.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_99.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_100.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_101.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_102.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_103.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_104.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_105.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_106.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_107.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_108.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_109.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_110.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_111.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_112.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_113.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_114.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_115.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_116.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_117.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_118.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_119.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_120.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_121.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_122.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_123.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_124.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_125.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_126.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_127.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_128.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_129.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_130.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_131.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_132.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_133.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_134.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_135.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_136.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_137.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_138.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_139.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_140.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_141.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_142.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_143.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_144.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_145.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_146.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_147.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_148.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_149.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_150.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_151.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_152.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_153.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_154.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_155.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_156.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_157.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_158.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_159.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_160.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_161.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_162.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_163.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_164.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_165.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_166.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_167.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_168.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_169.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_170.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_171.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_172.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_173.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_174.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_175.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_176.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_177.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_178.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_179.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_180.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_181.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_182.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_183.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_184.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_185.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_186.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_187.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_188.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_189.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_190.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_191.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_192.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_193.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_194.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_195.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_196.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_197.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_198.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_199.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_200.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_201.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_202.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_203.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_204.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_205.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_206.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_207.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_208.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_209.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_210.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_211.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_212.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_213.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_214.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_215.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_216.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_217.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_218.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_219.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_220.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_221.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_222.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_223.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_224.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_225.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_226.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_227.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_228.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_229.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_230.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_231.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_232.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_233.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_234.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_235.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_236.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_237.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_238.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_239.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_240.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_241.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_242.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_243.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_244.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_245.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_246.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_247.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_248.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_249.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo_250.png
# dst : /content/datasets/Plant/train/geumjeonsoo/geumjeonsoo
png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_465.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_466.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_467.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_468.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_469.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_470.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_471.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_472.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_473.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_474.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_475.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_476.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_477.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_478.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_479.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_480.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_481.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_482.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_483.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_484.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_485.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_486.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_487.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_488.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_489.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_490.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_491.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_492.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_493.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_494.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_495.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_496.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_497.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_498.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_499.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_500.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_501.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_502.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_503.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_504.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_505.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_506.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_507.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_508.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_509.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_510.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_511.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_512.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_513.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_514.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_515.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_516.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_517.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_518.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_519.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_520.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_521.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_522.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_523.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_524.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_525.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_526.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_527.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_528.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_529.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_530.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_531.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_532.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_533.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_534.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_535.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_536.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_537.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_538.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_539.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_540.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_541.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_542.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_543.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_544.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_545.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_546.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_547.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_548.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_549.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_550.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_551.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_552.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_553.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_554.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_555.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_556.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_557.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_558.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_559.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_560.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_561.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_562.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_563.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_564.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_565.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_566.png
# dst : /content/datasets/Plant/test/yeoincho/yeoincho_567.png
# stuckyi -test_dir len : 91
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_273.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_274.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_275.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_276.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_277.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_278.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_279.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_280.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_281.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_282.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_283.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_284.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_285.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_286.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_287.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_288.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_289.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_290.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_291.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_292.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_293.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_294.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_295.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_296.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_297.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_298.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_299.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_300.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_301.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_302.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_303.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_304.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_305.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_306.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_307.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_308.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_309.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_310.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_311.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_312.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_313.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_314.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_315.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_316.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_317.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_318.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_319.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_320.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_321.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_322.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_323.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_324.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_325.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_326.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_327.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_328.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_329.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_330.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_331.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_332.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_333.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_334.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_335.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_336.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_337.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_338.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_339.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_340.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_341.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_342.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_343.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_344.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_345.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_346.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_347.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_348.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_349.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_350.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_351.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_352.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_353.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_354.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_355.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_356.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_357.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_358.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_359.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_360.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_361.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_362.png
# dst : /content/datasets/Plant/test/stuckyi/stuckyi_363.png

# %%
# 안열리는 파일 삭제 
import PIL, glob
from PIL import Image
from os import remove

datalist = ['train', 'test', 'valid']

for data in datalist : 
    imgs_ = glob.glob(f"./datasets/Plant/{data}/*/*.png")

    for img in imgs_:
        try:
            img = PIL.Image.open(img)
        except PIL.UnidentifiedImageError:
            print(img)
            remove(img)
# Out:
# ./datasets/Plant/train/tableyaja/tableyaja_203.png
# ./datasets/Plant/test/geumjeonsoo/geumjeonsoo_1221.png
# ./datasets/Plant/test/monstera/monstera_425.png
# ./datasets/Plant/test/stuckyi/stuckyi_363.png
# ./datasets/Plant/test/yeoincho/yeoincho_567.png

# %%
for plant in plant_cnt:
    path_train = os.path.join('/content/datasets/Plant/train',plant)
    print(plant)
    print('훈련용 이미지 개수 : ', len(os.listdir(path_train)))

    # path_valid = os.path.join('/content/datasets/Plant/valid',plant)
    # print('valid 이미지 개수 : ', len(os.listdir(path_valid)))

    path_test = os.path.join('/content/datasets/Plant/test',plant)
    print('test 이미지 개수 : ', len(os.listdir(path_test)))
    print('-' * 40)
# Out:
# geumjeonsoo
# 훈련용 이미지 개수 :  754
# test 이미지 개수 :  377
# ----------------------------------------
# tableyaja
# 훈련용 이미지 개수 :  494
# test 이미지 개수 :  248
# ----------------------------------------
# monstera
# 훈련용 이미지 개수 :  212
# test 이미지 개수 :  106
# ----------------------------------------
# yeoincho
# 훈련용 이미지 개수 :  283
# test 이미지 개수 :  141
# ----------------------------------------
# stuckyi
# 훈련용 이미지 개수 :  181
# test 이미지 개수 :  90
# ----------------------------------------

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms

import numpy as np
import time


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # device 객체

# %%
# 데이터셋을 불러올 때 사용할 변형(transformation) 객체 정의
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(), # 데이터 증진(augmentation)
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

# transforms_vaild = transforms.Compose([
#     transforms.Resize((224, 224)),
#     transforms.ToTensor(),
#     transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
# ])

transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

data_dir = '/content/datasets/Plant'
train_datasets = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
# valid_datasets = datasets.ImageFolder(os.path.join(data_dir, 'valid'), transforms_vaild)
test_datasets = datasets.ImageFolder(os.path.join(data_dir, 'test'), transforms_test)

train_dataloader = torch.utils.data.DataLoader(train_datasets, batch_size=2, shuffle=True, num_workers=2)
# valid_dataloader = torch.utils.data.DataLoader(valid_datasets, batch_size=2, shuffle=True, num_workers=2)
test_dataloader = torch.utils.data.DataLoader(test_datasets, batch_size=2, shuffle=True, num_workers=2)

print('학습 데이터셋 크기:', len(train_datasets))
# print('검증 데이터셋 크기:', len(valid_datasets))
print('테스트 데이터셋 크기:', len(test_datasets))

class_names = train_datasets.classes
print('클래스:', class_names)
# Out:
# 학습 데이터셋 크기: 1924
# 테스트 데이터셋 크기: 962
# 클래스: ['geumjeonsoo', 'monstera', 'stuckyi', 'tableyaja', 'yeoincho']

# %%
def imshow(input, title):
    # torch.Tensor를 numpy 객체로 변환
    input = input.numpy().transpose((1, 2, 0)) # 배치, 채널, 높이, 너비 순 -> 채널 값을 가장 뒤로 바꿔줌
    # 이미지 정규화 해제하기
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # 이미지 출력
    plt.imshow(input)
    plt.title(title)
    plt.show()


# 학습 데이터를 배치 단위로 불러오기
iterator = iter(train_dataloader)

# 현재 배치를 이용해 격자 형태의 이미지를 만들어 시각화
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %%
model = models.resnet50(pretrained=True)
num_features = model.fc.in_features
# 전이 학습(transfer learning): 모델의 출력 뉴런 수를 3개로 교체하여 마지막 레이어 다시 학습
model.fc = nn.Linear(num_features, 5) # 우리가 내보낼 채널의 수 -> 현재 5가지 식물
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
num_epochs = 5
model.train()
start_time = time.time()

# 전체 반복(epoch) 수 만큼 반복하며
for epoch in range(num_epochs):
    running_loss = 0.
    running_corrects = 0

    # 배치 단위로 학습 데이터 불러오기
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # 모델에 입력(forward)하고 결과 계산
        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # 역전파를 통해 기울기(gradient) 계산 및 학습 진행
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_datasets)
    epoch_acc = running_corrects / len(train_datasets) * 100.

    # 학습 과정 중에 결과 출력
    print('#{} Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch, epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# #0 Loss: 1.1870 Acc: 60.2391% Time: 1371.6264s
# #1 Loss: 0.7062 Acc: 78.4304% Time: 2751.2609s
# #2 Loss: 0.4359 Acc: 87.3701% Time: 4119.6880s
# #3 Loss: 0.3309 Acc: 90.4886% Time: 5494.1005s
# #4 Loss: 0.2219 Acc: 93.8669% Time: 6845.3615s

# %%
model.eval()
start_time = time.time()

with torch.no_grad():
    running_loss = 0.
    running_corrects = 0

    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        # 한 배치의 첫 번째 이미지에 대하여 결과 시각화
        print(f'[예측 결과: {class_names[preds[0]]}] (실제 정답: {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])

    epoch_loss = running_loss / len(test_datasets)
    epoch_acc = running_corrects / len(test_datasets) * 100.
    print('[Test Phase] Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 모델 저장
torch.save(model, '/content/drive/MyDrive/Colab/all/model.pth')

# %%
# 모델 불러오기
model = torch.load('/content/drive/MyDrive/Colab/all/model.pth')

# %%
# # 모델 저장
# PATH = '/content/model/'

# torch.save(model, PATH + 'model.pt')  # 전체 모델 저장
# torch.save(model.state_dict(), PATH + 'model_state_dict.pt')  # 모델 객체의 state_dict 저장
# torch.save({
#     'model': model.state_dict(),
#     'optimizer': optimizer.state_dict()
# }, PATH + 'all.tar')  # 여러 가지 값 저장, 학습 중 진행 상황 저장을 위해 epoch, loss 값 등 일반 scalar값 저장 가능

# %%
# 모델 불러와서 다시 검사
model.eval()
start_time = time.time()

with torch.no_grad():
    running_loss = 0.
    running_corrects = 0

    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        # 한 배치의 첫 번째 이미지에 대하여 결과 시각화
        print(f'[예측 결과: {class_names[preds[0]]}] (실제 정답: {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])

    epoch_loss = running_loss / len(test_datasets)
    epoch_acc = running_corrects / len(test_datasets) * 100.
    print('[Test Phase] Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
num_epochs = 50
model.train()
start_time = time.time()

# 전체 반복(epoch) 수 만큼 반복하며
for epoch in range(num_epochs):
    running_loss = 0.
    running_corrects = 0

    # 배치 단위로 학습 데이터 불러오기
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # 모델에 입력(forward)하고 결과 계산
        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # 역전파를 통해 기울기(gradient) 계산 및 학습 진행
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_datasets)
    epoch_acc = running_corrects / len(train_datasets) * 100.

    # 학습 과정 중에 결과 출력
    print('#{} Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch, epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-7b0e2a6f0939> in <module>()
#      15         # 모델에 입력(forward)하고 결과 계산
#      16         optimizer.zero_grad()
# ---> 17         outputs = model(inputs)
#      18         _, preds = torch.max(outputs, 1)
#      19         loss = criterion(outputs, labels)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torchvision/models/resnet.py in forward(self, x)
#     247
#     248     def forward(self, x: Tensor) -> Tensor:
# --> 249         return self._forward_impl(x)
#     250
#     251
#
# /usr/local/lib/python3.7/dist-packages/torchvision/models/resnet.py in _forward_impl(self, x)
#     237         x = self.layer1(x)
#     238         x = self.layer2(x)
# --> 239         x = self.layer3(x)
#     240         x = self.layer4(x)
#     241
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torchvision/models/resnet.py in forward(self, x)
#     130         out = self.relu(out)
#     131
# --> 132         out = self.conv3(out)
#     133         out = self.bn3(out)
#     134
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
# --> 446         return self._conv_forward(input, self.weight, self.bias)
#     447
#     448 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     441                             _pair(0), self.dilation, self.groups)
#     442         return F.conv2d(input, weight, bias, self.stride,
# --> 443                         self.padding, self.dilation, self.groups)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:
