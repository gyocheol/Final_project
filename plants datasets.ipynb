# %%
import os

path = "./datasets/all"
image_list = os.listdir(path)
image_list_png = [image for image in image_list if image.endswith(".png")]

print('image_list_png :{}'.format(image_list_png))
# Out:
# image_list_png :['geumjeonsoo1.png', 'geumjeonsoo100.png', 'geumjeonsoo101.png', 'geumjeonsoo103.png', 'geumjeonsoo106.png', 'geumjeonsoo11.png', 'geumjeonsoo111.png', 'geumjeonsoo113.png', 'geumjeonsoo12.png', 'geumjeonsoo123.png', 'geumjeonsoo124.png', 'geumjeonsoo125.png', 'geumjeonsoo126.png', 'geumjeonsoo128.png', 'geumjeonsoo129.png', 'geumjeonsoo13.png', 'geumjeonsoo130.png', 'geumjeonsoo131.png', 'geumjeonsoo136.png', 'geumjeonsoo137.png', 'geumjeonsoo138.png', 'geumjeonsoo140.png', 'geumjeonsoo141.png', 'geumjeonsoo145.png', 'geumjeonsoo149.png', 'geumjeonsoo150.png', 'geumjeonsoo158.png', 'geumjeonsoo16.png', 'geumjeonsoo161.png', 'geumjeonsoo163.png', 'geumjeonsoo167.png', 'geumjeonsoo170.png', 'geumjeonsoo173.png', 'geumjeonsoo175.png', 'geumjeonsoo176.png', 'geumjeonsoo183.png', 'geumjeonsoo185.png', 'geumjeonsoo186.png', 'geumjeonsoo188.png', 'geumjeonsoo2.png', 'geumjeonsoo20.png', 'geumjeonsoo200.png', 'geumjeonsoo203.png', 'geumjeonsoo206.png', 'geumjeonsoo209.png', 
# ...

# %%
import PIL
import glob

imgs = glob.glob('/datasets/all/*.png')

for img in imgs:
    try:
        img = PIL.Image.open(img)
    except PIL.UnidentifiedImageError:
        print(img)

# %%
import tensorflow as tf
import os, shutil

# %%
import os, shutil

# 원본 데이터 압축 해제한 디렉토리 경로
original_dataset_dir = './datasets/all'

# 소규모 데이터셋 저장 디렉토리
base_dir = './datasets/plants'

os.mkdir(base_dir)

# 훈련, 검증, 테스트 분할을 위한 디렉토리
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

# 훈련용 식물이미지 디렉토리

train_geumjeonsoo_dir = os.path.join(train_dir, 'geumjeonsoo')
os.mkdir(train_geumjeonsoo_dir)
train_stuckyi_dir = os.path.join(train_dir, 'stuckyi')
os.mkdir(train_stuckyi_dir)
# train_tableyaja_dir = os.path.join(train_dir, 'tableyaja')
# os.mkdir(train_tableyaja_dir)

# 검증용 식물 이미지 디렉토리
validation_geumjeonsoo_dir = os.path.join(validation_dir, 'geumjeonsoo')
os.mkdir(validation_geumjeonsoo_dir)
validation_stuckyi_dir = os.path.join(validation_dir, 'stuckyi')
os.mkdir(validation_stuckyi_dir)
# validation_tableyaja_dir = os.path.join(validation_dir, 'tableyaja')
# os.mkdir(validation_tableyaja_dir)

# 테스트용 식물 이미지 디렉토리
test_geumjeonsoo_dir = os.path.join(test_dir, 'geumjeonsoo')
os.mkdir(test_geumjeonsoo_dir)
test_stuckyi_dir = os.path.join(test_dir, 'stuckyi')
os.mkdir(test_stuckyi_dir)
# test_tableyaja_dir = os.path.join(test_dir, 'tableyaja')
# os.mkdir(test_tableyaja_dir)

# %%
# 100개의 이미지를 train에 복사
fnames = [image_list_png[i] for i in range(100)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_geumjeonsoo_dir, fname)
    shutil.copyfile(src, dst)

# 50개의 이미지를 validation에 복사
fnames = [image_list_png[i] for i in range(100, 150)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_geumjeonsoo_dir, fname)
    shutil.copyfile(src, dst)

# 50개의 이미지를 test에 복사
fnames = [image_list_png[i] for i in range(150, 200)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(test_geumjeonsoo_dir, fname)
    shutil.copyfile(src, dst)


# 100개의 이미지를 train에 복사
fnames = [image_list_png[i] for i in range(200, 300)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_stuckyi_dir, fname)
    shutil.copyfile(src, dst)

# 50개의 이미지를 validation에 복사
fnames = [image_list_png[i] for i in range(300, 350)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_stuckyi_dir, fname)
    shutil.copyfile(src, dst)

# 50개의 이미지를 test에 복사
fnames = [image_list_png[i] for i in range(350, 400)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(test_stuckyi_dir, fname)
    shutil.copyfile(src, dst)


# # 100개의 이미지를 train에 복사
# fnames = [image_list_png[i] for i in range(400, 500)]
# for fname in fnames:
#     src = os.path.join(original_dataset_dir, fname)
#     dst = os.path.join(train_tableyaja_dir, fname)
#     shutil.copyfile(src, dst)

# # 50개의 이미지를 validation에 복사
# fnames = [image_list_png[i] for i in range(500, 550)]
# for fname in fnames:
#     src = os.path.join(original_dataset_dir, fname)
#     dst = os.path.join(validation_tableyaja_dir, fname)
#     shutil.copyfile(src, dst)

# # 50개의 이미지를 test에 복사
# fnames = [image_list_png[i] for i in range(550, 600)]
# for fname in fnames:
#     src = os.path.join(original_dataset_dir, fname)
#     dst = os.path.join(test_tableyaja_dir, fname)
#     shutil.copyfile(src, dst)

# %%
print('훈련용 금전수 이미지 전체 개수 : ', len(os.listdir(train_geumjeonsoo_dir)))
print('훈련용 스투키 이미지 전체 개수 : ', len(os.listdir(train_stuckyi_dir)))
# print('훈련용 테이블야자 이미지 전체 개수 : ', len(os.listdir(train_tableyaja_dir)))

print('검증용 금전수 이미지 전체 개수 : ', len(os.listdir(validation_geumjeonsoo_dir)))
print('검증용 스투키 이미지 전체 개수 : ', len(os.listdir(validation_stuckyi_dir)))
# print('검증용 테이블야자 이미지 전체 개수 : ', len(os.listdir(validation_tableyaja_dir)))

print('테스트용 금전수 이미지 전체 개수 : ', len(os.listdir(test_geumjeonsoo_dir)))
print('테스트용 스투키 이미지 전체 개수 : ', len(os.listdir(test_stuckyi_dir)))
# print('테스트용 테이블야자 이미지 전체 개수 : ', len(os.listdir(test_tableyaja_dir)))
# Out:
# 훈련용 금전수 이미지 전체 개수 :  100
# 훈련용 스투키 이미지 전체 개수 :  100
# 검증용 금전수 이미지 전체 개수 :  50
# 검증용 스투키 이미지 전체 개수 :  50
# 테스트용 금전수 이미지 전체 개수 :  50
# 테스트용 스투키 이미지 전체 개수 :  50

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 1)                 513
#
# ...
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# ...

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes=True)

# %%
# 모델 훈련 설정 및 컴파일
from tensorflow.keras.optimizers import RMSprop

optimizer = RMSprop(learning_rate=1e-04)

model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
# 전처리
# ImageDataGenerator를 사용하여 디렉터리에서 이미지 읽기

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150, 150),
    batch_size = 20,
    class_mode='binary'
)

validation_generator = test_datagen.flow_from_directory(
    validation_dir,
    target_size = (150, 150),
    batch_size = 20,
    class_mode='binary'
)
# Out:
# Found 200 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
# 모델 훈련
# 배치 제너레이터를 사용하여 모델 훈련

history = model.fit(
    train_generator,
    steps_per_epoch=50,
    epochs=1,  
    validation_data=validation_generator,
    validation_steps=100
)
# Out:
# 10/50 [=====>........................] - ETA: 14s - loss: 0.2454 - accuracy: 0.9000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 50 batches). You may need to use the repeat() function when building your dataset.
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 100 batches). You may need to use the repeat() function when building your dataset.
# 50/50 [==============================] - 4s 79ms/step - loss: 0.2454 - accuracy: 0.9000 - val_loss: 0.2477 - val_accuracy: 0.9000

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid()
plt.legend()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_generator = test_datagen.flow_from_directory(
                 test_dir,
                 target_size = (150, 150),
                 batch_size = 20,
                 class_mode = 'binary')
# Out:
# Found 100 images belonging to 2 classes.

# %%
loss, accuracy = model.evaluate(test_generator,
                                steps = 50)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# ...
# 50/50 [==============================] - 1s 12ms/step - loss: 0.6824 - accuracy: 0.5000
# Loss = 0.68244
# Accuracy = 0.50000

# %%
# 모델 저장
# model.save('./model/plants.h5')

# %%
# 모델 로드
# from tensorflow.keras.models import load_model

# model_path = './model/plants.h5'
# model_small = load_model(model_path)

# %%
# loss, accuracy = model_small.evaluate(test_generator,
#                                       steps = 50)

# print('Loss = {:.5f}'.format(loss))
# print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# ...
# 50/50 [==============================] - 1s 12ms/step - loss: 0.6788 - accuracy: 0.5400
# Loss = 0.67885
# Accuracy = 0.54000
